# %% [markdown]
# # Práctica Clase 2

# %% [markdown]
# 1) Abrir el archivo "Emisiones_CO2.csv" y cargar sus datos en un diccionario.

# %%
import os
archivo = open('Emisiones_CO2.csv', 'r')

# %%
dicc_emisiones = {  'cod_pais' : [],
                    'nom_pais' : [],
                    'region' : [],
                    'anio' : [],
                    'co2' : [],
                    'co2_percapita' : []}


lineas = archivo.readlines()

#ciclo para evaluar linea por linea e ir evaluando, separando valores por delimitador "|"
i = 0
for linea in lineas:
    dato = linea.split('|')
    if i == 0:
        pass
    else:
        dicc_emisiones['cod_pais'].append(dato[0])
        dicc_emisiones['nom_pais'].append(dato[1])
        dicc_emisiones['region'].append(dato[2])
        dicc_emisiones['anio'].append(dato[3])
        dicc_emisiones['co2'].append(dato[4])
        dicc_emisiones['co2_percapita'].append(dato[5])
    i+=1

dicc_emisiones
# Out:
# {'cod_pais': ['ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'ABW',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
#   'AND',
# ...

# %% [markdown]
# 2) a) ¿Cuántas variables hay? <br>
# b) ¿Qué tipos de datos usar para cada una? <br>
# c) ¿Qué tipo de variables son? <br>
# d) ¿Hay valores faltantes? <br>
# e) ¿Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?

# %%
# Cuántas variables hay?

#el diccionario corresponde a un dataset de dimentiones NxM
print(f"Hay {dicc_emisiones['cod_pais'].__len__()*dicc_emisiones.__len__()} variables")
dicc_emisiones['cod_pais'].__len__()*dicc_emisiones.__len__()
# Out:
# Hay 66762 variables
# 66762

# %%
# Qué tipos de datos usar para cada una?

#cod_pais string
#nom_pais string
#region string
#anio int
#co2 float
#co2_percapita float
# Out:
# str

# %%
# Qué tipo de variables son?

type(dicc_emisiones['cod_pais'][0])
# Out:
# str

# %%
# Hay valores faltantes? Si

dicc_emisiones['co2']
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '179,683',
#  '447,374',
#  '612,389',
#  '649,059',
#  '1.840,83',
#  '1.928,84',
#  '1.723,49',
#  '1.771,16',
#  '1.763,83',
#  '1.782,16',
#  '1.800,50',
#  '1.837,17',
#  '1.712,49',
#  '1.749,16',
#  '2.321,21',
#  '2.357,88',
#  '2.372,55',
#  '2.416,55',
#  '2.420,22',
#  '2.497,23',
#  '2.497,23',
#  '2.592,57',
#  '2.508,23',
#  '2.522,90',
#  '2.456,89',
#  '2.438,56',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '407,037',
#  '425,372',
#  '458,375',
#  '484,044',
#  '513,38',
#  '524,381',
#  '524,381',
#  '531,715',
#  '535,382',
#  '564,718',
#  '575,719',
#  '546,383',
#  '539,049',
# ...

# %%
# Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?

positivas = []

for indice,valor in enumerate(dicc_emisiones['region']):
    if valor == 'América Latina y Caribe' and dicc_emisiones['anio'][indice] == '2010':
        if dicc_emisiones['co2'][indice] != '':
            positivas.append(dicc_emisiones['co2'][indice])
positivas
# Out:
# ['2.456,89',
#  '179.000,94',
#  '524,381',
#  '2.464,22',
#  '553,717',
#  '15.350,06',
#  '419.754,16',
#  '1.518,14',
#  '72.258,24',
#  '78.583,81',
#  '7.568,69',
#  '38.360,49',
#  '564,718',
#  '135,679',
#  '21.363,94',
#  '34.249,78',
#  '260,357',
#  '11.367,70',
#  '1.719,82',
#  '8.107,74',
#  '2.119,53',
#  '7.190,99',
#  '260,357',
#  '403,37',
#  '445.063,79',
#  '4.624,09',
#  '8.866,81',
#  '57.857,93',
#  '5.075,13',
#  '6.307,24',
#  '2.394,55',
#  '190,684',
#  '50.916,30',
#  '6.453,92',
#  '234,688',
#  '197.511,95']

# %%
suma = 0

for indice,valor in enumerate(positivas):
    suma += float(positivas[indice].replace('.','').replace(',','.'))

print(f'Total de emisiones de CO2 para América Latina y Caribe en el año 2010: {suma:.2f}')
# Out:
# Total de emisiones de CO2 para América Latina y Caribe en el año 2010: 1691634.80

# %%
import pandas as pd

df=pd.DataFrame.from_dict(dicc_emisiones)
df.head()
# Out:
#   cod_pais nom_pais                   region  anio co2 co2_percapita
# 0      ABW    Aruba  América Latina y Caribe  1960                \n
# 1      ABW    Aruba  América Latina y Caribe  1961                \n
# 2      ABW    Aruba  América Latina y Caribe  1962                \n
# 3      ABW    Aruba  América Latina y Caribe  1963                \n
# 4      ABW    Aruba  América Latina y Caribe  1964                \n

# %%
res = df.loc[(df['region'] == 'América Latina y Caribe') & (df['anio']=='2010')]
res['co2'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\Users\ccook\Desktop\DataSoyHenry\Clases\DS-M1\Clase 02\Homework.ipynb Cell 10' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/Users/ccook/Desktop/DataSoyHenry/Clases/DS-M1/Clase%2002/Homework.ipynb#ch0000009?line=0'>1</a> res = df.loc[(df['region'] == 'América Latina y Caribe') & (df['anio']=='2010')]
# ----> <a href='vscode-notebook-cell:/e%3A/Users/ccook/Desktop/DataSoyHenry/Clases/DS-M1/Clase%2002/Homework.ipynb#ch0000009?line=1'>2</a> res['co2'].astype(float)
#
# File e:\Program Files\Python310\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# ...
